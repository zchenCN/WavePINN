# %%
import numpy as np 
from matplotlib import pyplot as plt
from acoustic1d import gen_data

# %%
C0 = np.ones(201)
u = gen_data(C0)
# Out:
# ns = 201, nt= 3600, max absolute of u=1.7365e-02, max absolute of f=5.6419e+00

# %%
u.shape
# Out:
# (3600, 201)

# %%
u.max(), u.min()
# Out:
# (0.017364744785247722, -0.015570935076758908)

# %%
plt.plot(u[500])
