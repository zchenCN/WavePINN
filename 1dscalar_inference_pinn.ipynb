# %%
import numpy as np
from scipy.io import loadmat
from matplotlib import pyplot as plt
import torch
import torch.nn as nn
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f'Device = {device}')
# Out:
# Device = cuda

# %% [markdown]
# To verify the ability of **PINN**(Physics Informed Neural Networks) for solving wave equations, we test it on the following 1d homogenenous wave equation:
# \begin{equation}
# \begin{split}
# &u_{tt} - c^2u_{xx} = 0, -1 < x < 1, t > 0 \\
# &u(-1, t) = u(1, t) = 0\\
# &u(x, 0) = \cos\frac{\pi x}{2}, u_t(x, 0) = 0
# \end{split}
# \end{equation}
# The theoretical solution of it is:
# $$ u(x, t) = \cos\frac{\pi ct}{2}\cos\frac{\pi x}{2}$$

# %%
class DNN(nn.Module):
    """Fully connected neural network
    """
    def __init__(self, layer_sizes):
        super(DNN, self).__init__()
        self.layer_sizes = layer_sizes
        self.linears = nn.ModuleList()
        for i in range(1, len(layer_sizes)):
            self.linears.append(nn.Linear(layer_sizes[i-1], layer_sizes[i]))

    def forward(self, x):
        for linear in self.linears[:-1]:
            # x = torch.nn.functional.softplus(linear(x))
            # x = torch.sigmoid(linear(x))
            # x = torch.nn.functional.relu(linear(x))
            # x = torch.tanh(linear(x))
            x = torch.sin(linear(x))
        x = self.linears[-1](x)
        return x

# %%
class PINN(nn.Module):
    """Physic informed neural network
    """
    def __init__(self, c, A, layer_sizes, Ni, Nb, Nc):
        super(PINN, self).__init__()
        self.c = c
        self.A = A
        # Initial condition
        xi = np.random.uniform(-1, 1, (Ni, 1))
        self.xi = torch.tensor(xi, dtype=torch.float32, requires_grad=True, device=device)
        self.ti = torch.zeros(Ni, 1, dtype=torch.float32, requires_grad=True, device=device)
        ui = np.cos(np.pi * xi / 2) * A
        self.ui = torch.tensor(ui, dtype=torch.float32, device=device)
        
        # Boundary condition
        tl = np.random.uniform(0, 1, (Nb, 1))
        xl = np.ones((Nb, 1)) * (-1)
        self.tl = torch.tensor(tl, dtype=torch.float32, requires_grad=True, device=device)
        self.xl = torch.tensor(xl, dtype=torch.float32, requires_grad=True, device=device)
        tr = np.random.uniform(0, 1, (Nb, 1))
        xr = np.ones((Nb, 1))  
        self.tr = torch.tensor(tr, dtype=torch.float32, requires_grad=True, device=device)
        self.xr = torch.tensor(xr, dtype=torch.float32, requires_grad=True, device=device)        
        
        # Collocation points
        xf = np.random.uniform(-1, 1, (Nc, 1))
        tf = np.random.uniform(0, 1, (Nc, 1))
        self.xf = torch.tensor(xf, dtype=torch.float32, requires_grad=True, device=device)
        self.tf = torch.tensor(tf, dtype=torch.float32, requires_grad=True, device=device)
        
        # Deal with l2 error
        self.error = []
        t_star = np.linspace(0, 1, 200)[:, None]
        x_star = np.linspace(0, 1, 200)[:, None]
        X_star, T_star = np.meshgrid(x_star, t_star)
        self.t_star = T_star.flatten()[:,None]
        self.x_star = X_star.flatten()[:,None]
        self.u_star = np.cos(np.pi * c * self.t_star / 2) * np.cos(np.pi * self.x_star / 2) * A
            
        self.loss = []
        self.dnn = DNN(layer_sizes).to(device)
        self.iter = 0
        self.max_num_iter = 5000
        self.optimizer = torch.optim.LBFGS(
            self.dnn.parameters(), 
            lr=1.0, 
            max_iter=50000, 
            max_eval=50000, 
            history_size=50,
            tolerance_grad=1e-5, 
            tolerance_change=1.0 * np.finfo(float).eps,
            line_search_fn="strong_wolfe"       # can be "strong_wolfe"
        )
        
#         self.optimizer = torch.optim.Adam(
#             self.dnn.parameters(), 
#             lr=0.01, 
#         )
        
    def net_u(self, x, t):
        u = self.dnn(torch.cat((x, t), dim=1))
        return u 

    def net_f(self, x, t):
        u = self.net_u(x, t)

        u_t = torch.autograd.grad(
            u, t, 
            grad_outputs=torch.ones_like(u),
            retain_graph=True,
            create_graph=True
        )[0]
        
        u_tt = torch.autograd.grad(
            u_t, t, 
            grad_outputs=torch.ones_like(u_t),
            retain_graph=True,
            create_graph=True
        )[0]

        u_x = torch.autograd.grad(
            u, x, 
            grad_outputs=torch.ones_like(u),
            retain_graph=True,
            create_graph=True
        )[0]

        u_xx = torch.autograd.grad(
            u_x, x, 
            grad_outputs=torch.ones_like(u_x),
            retain_graph=True,
            create_graph=True
        )[0]

        Lu = u_tt  - self.c ** 2 * u_xx
        return Lu 
    
#     def initial_loss(self):
#         u = self.net_u(self.xi, self.ti)
#         li = torch.mean(torch.square(u - self.ui))
#         self.loss_i.append(li.item())
#         return li
    
#     def boundary_loss(self):
#         ul = self.net_u(self.xl, self.tl)
#         ur = self.net_u(self.xr, self.tr)
#         lb = torch.mean(torch.square(ul)) +\
#              torch.mean(torch.square(ur))
#         self.loss_b.append(lb.item())
#         return lb
                        
#     def collocation_loss(self):
#         Lu = self.net_f(self.xf, self.tf)
#         lc = torch.mean(torch.square(Lu))
#         self.loss_c.append(lc.item())
#         return lc

    def compute_error(self):
        self.dnn.eval()
        u_pred, _ = self.predict(self.x_star, self.t_star)
        error = np.linalg.norm(self.u_star-u_pred,2)/np.linalg.norm(self.u_star,2)
        error = error ** 2
        self.error.append(error)
        self.dnn.train()

    def loss_func(self):
        self.compute_error()
        self.optimizer.zero_grad()
        
        ui = self.net_u(self.xi, self.ti)
        ui_t = torch.autograd.grad(
            ui, self.ti,
            grad_outputs=torch.ones_like(ui),
            retain_graph=True,
            create_graph=True
        )[0]
        loss_i = torch.mean((self.ui - ui) ** 2) + torch.mean(ui_t ** 2)
        
        f_pred = self.net_f(self.xf, self.tf)
        loss_f = torch.mean(f_pred ** 2)
        
        ul = self.net_u(self.xl, self.tl)
        ur = self.net_u(self.xr, self.tr)
        loss_b = torch.mean(ul ** 2) + torch.mean(ur ** 2)

        loss = loss_i + loss_b +  loss_f
        self.loss.append(loss.item())
        
        loss.backward()
        
        if self.iter % 500 == 0:
            print("Iter %d, Loss: %.4e, Initial loss: %.4e, Boundary loss: %.4e, Collocation loss : %.4e" 
                  % (self.iter, loss.item(), loss_i.item(), loss_b.item(), loss_f.item()))
        self.iter += 1
        return loss
    
    # def compute_loss(self):
    #     self.optimizer.zero_grad()
    #     li = self.initial_loss()
    #     lb = self.boundary_loss()
    #     lc = self.collocation_loss()
    #     l = li + lb + lc 
    #     l.backward()
    #     self.loss.append(l.item())
    #     self.num_iter += 1
    #     if self.num_iter % 500 == 0 or self.num_iter == self.max_num_iter:
    #         self.loss.append(l.item())
    #         print("Iter %d, Loss: %.4e, Initial loss: %.4e, Boundary loss: %.4e, Collocation loss : %.4e" 
    #               % (self.num_iter, l.item(), li.item(), lb.item(), lc.item()))
    #     return l

    def train(self):
        self.dnn.train()
        while self.iter < self.max_num_iter:
            self.optimizer.step(self.loss_func)

            
    def predict(self, x, t):
        self.dnn.eval() 
        x = torch.tensor(x, requires_grad=True, dtype=torch.float32, device=device)
        t = torch.tensor(t, requires_grad=True, dtype=torch.float32, device=device)
        u = self.net_u(x, t)
        Lu = self.net_f(x, t)
        u = u.detach().cpu().numpy()
        Lu = Lu.detach().cpu().numpy()
        return u, Lu

# %%
c = 1
A = 1
Ni = 200
Nb = 200
Nc = 10000
layer_sizes = [2] + [20] * 5 + [1]
model = PINN(c, A, layer_sizes, Ni, Nb, Nc)
model.train()
# Out:
# Iter 0, Loss: 5.7674e-01, Initial loss: 5.7123e-01, Boundary loss: 5.4819e-03, Collocation loss : 2.5015e-05
# Iter 100, Loss: 3.6913e-04, Initial loss: 1.8858e-04, Boundary loss: 1.0289e-04, Collocation loss : 7.7664e-05
# Iter 200, Loss: 3.6950e-04, Initial loss: 1.9045e-04, Boundary loss: 1.0331e-04, Collocation loss : 7.5748e-05
# Iter 300, Loss: 3.6903e-04, Initial loss: 1.8848e-04, Boundary loss: 1.0288e-04, Collocation loss : 7.7670e-05
# Iter 400, Loss: 3.6993e-04, Initial loss: 1.8903e-04, Boundary loss: 1.0339e-04, Collocation loss : 7.7504e-05
# Iter 500, Loss: 3.6950e-04, Initial loss: 1.9045e-04, Boundary loss: 1.0331e-04, Collocation loss : 7.5748e-05
# Iter 600, Loss: 3.6903e-04, Initial loss: 1.8848e-04, Boundary loss: 1.0288e-04, Collocation loss : 7.7670e-05
# Iter 700, Loss: 3.6993e-04, Initial loss: 1.8903e-04, Boundary loss: 1.0339e-04, Collocation loss : 7.7504e-05
# Iter 800, Loss: 3.6950e-04, Initial loss: 1.9045e-04, Boundary loss: 1.0331e-04, Collocation loss : 7.5748e-05
# Iter 900, Loss: 3.6903e-04, Initial loss: 1.8848e-04, Boundary loss: 1.0288e-04, Collocation loss : 7.7670e-05
# Iter 1000, Loss: 3.6993e-04, Initial loss: 1.8903e-04, Boundary loss: 1.0339e-04, Collocation loss : 7.7504e-05
# Iter 1100, Loss: 3.6950e-04, Initial loss: 1.9045e-04, Boundary loss: 1.0331e-04, Collocation loss : 7.5748e-05
# Iter 1200, Loss: 3.6903e-04, Initial loss: 1.8848e-04, Boundary loss: 1.0288e-04, Collocation loss : 7.7670e-05
# Iter 1300, Loss: 3.6993e-04, Initial loss: 1.8903e-04, Boundary loss: 1.0339e-04, Collocation loss : 7.7504e-05
# Iter 1400, Loss: 3.6950e-04, Initial loss: 1.9045e-04, Boundary loss: 1.0331e-04, Collocation loss : 7.5748e-05
# Iter 1500, Loss: 3.6903e-04, Initial loss: 1.8848e-04, Boundary loss: 1.0288e-04, Collocation loss : 7.7670e-05
# Iter 1600, Loss: 3.6993e-04, Initial loss: 1.8903e-04, Boundary loss: 1.0339e-04, Collocation loss : 7.7504e-05
# Iter 1700, Loss: 3.6950e-04, Initial loss: 1.9045e-04, Boundary loss: 1.0331e-04, Collocation loss : 7.5748e-05
# Iter 1800, Loss: 3.6903e-04, Initial loss: 1.8848e-04, Boundary loss: 1.0288e-04, Collocation loss : 7.7670e-05
# Iter 1900, Loss: 3.6993e-04, Initial loss: 1.8903e-04, Boundary loss: 1.0339e-04, Collocation loss : 7.7504e-05
# Iter 2000, Loss: 3.6950e-04, Initial loss: 1.9045e-04, Boundary loss: 1.0331e-04, Collocation loss : 7.5748e-05
# Iter 2100, Loss: 3.6903e-04, Initial loss: 1.8848e-04, Boundary loss: 1.0288e-04, Collocation loss : 7.7670e-05
# Iter 2200, Loss: 3.6993e-04, Initial loss: 1.8903e-04, Boundary loss: 1.0339e-04, Collocation loss : 7.7504e-05
# Iter 2300, Loss: 3.6950e-04, Initial loss: 1.9045e-04, Boundary loss: 1.0331e-04, Collocation loss : 7.5748e-05
# Iter 2400, Loss: 3.6903e-04, Initial loss: 1.8848e-04, Boundary loss: 1.0288e-04, Collocation loss : 7.7670e-05
# Iter 2500, Loss: 3.6993e-04, Initial loss: 1.8903e-04, Boundary loss: 1.0339e-04, Collocation loss : 7.7504e-05
# Iter 2600, Loss: 3.6950e-04, Initial loss: 1.9045e-04, Boundary loss: 1.0331e-04, Collocation loss : 7.5748e-05
# Iter 2700, Loss: 3.6903e-04, Initial loss: 1.8848e-04, Boundary loss: 1.0288e-04, Collocation loss : 7.7670e-05
# Iter 2800, Loss: 3.6993e-04, Initial loss: 1.8903e-04, Boundary loss: 1.0339e-04, Collocation loss : 7.7504e-05
# Iter 2900, Loss: 3.6950e-04, Initial loss: 1.9045e-04, Boundary loss: 1.0331e-04, Collocation loss : 7.5748e-05
# Iter 3000, Loss: 3.6903e-04, Initial loss: 1.8848e-04, Boundary loss: 1.0288e-04, Collocation loss : 7.7670e-05
# Iter 3100, Loss: 3.6993e-04, Initial loss: 1.8903e-04, Boundary loss: 1.0339e-04, Collocation loss : 7.7504e-05
# Iter 3200, Loss: 3.6950e-04, Initial loss: 1.9045e-04, Boundary loss: 1.0331e-04, Collocation loss : 7.5748e-05
# Iter 3300, Loss: 3.6903e-04, Initial loss: 1.8848e-04, Boundary loss: 1.0288e-04, Collocation loss : 7.7670e-05
# Iter 3400, Loss: 3.6993e-04, Initial loss: 1.8903e-04, Boundary loss: 1.0339e-04, Collocation loss : 7.7504e-05
# Iter 3500, Loss: 3.6950e-04, Initial loss: 1.9045e-04, Boundary loss: 1.0331e-04, Collocation loss : 7.5748e-05
# Iter 3600, Loss: 3.6903e-04, Initial loss: 1.8848e-04, Boundary loss: 1.0288e-04, Collocation loss : 7.7670e-05
# Iter 3700, Loss: 3.6993e-04, Initial loss: 1.8903e-04, Boundary loss: 1.0339e-04, Collocation loss : 7.7504e-05
# Iter 3800, Loss: 3.6950e-04, Initial loss: 1.9045e-04, Boundary loss: 1.0331e-04, Collocation loss : 7.5748e-05
# Iter 3900, Loss: 3.6903e-04, Initial loss: 1.8848e-04, Boundary loss: 1.0288e-04, Collocation loss : 7.7670e-05
# Iter 4000, Loss: 3.6993e-04, Initial loss: 1.8903e-04, Boundary loss: 1.0339e-04, Collocation loss : 7.7504e-05
# Iter 4100, Loss: 3.6950e-04, Initial loss: 1.9045e-04, Boundary loss: 1.0331e-04, Collocation loss : 7.5748e-05
# Iter 4200, Loss: 3.6903e-04, Initial loss: 1.8848e-04, Boundary loss: 1.0288e-04, Collocation loss : 7.7670e-05
# Iter 4300, Loss: 3.6993e-04, Initial loss: 1.8903e-04, Boundary loss: 1.0339e-04, Collocation loss : 7.7504e-05
# Iter 4400, Loss: 3.6950e-04, Initial loss: 1.9045e-04, Boundary loss: 1.0331e-04, Collocation loss : 7.5748e-05
# Iter 4500, Loss: 3.6903e-04, Initial loss: 1.8848e-04, Boundary loss: 1.0288e-04, Collocation loss : 7.7670e-05
# Iter 4600, Loss: 3.6993e-04, Initial loss: 1.8903e-04, Boundary loss: 1.0339e-04, Collocation loss : 7.7504e-05
# Iter 4700, Loss: 3.6950e-04, Initial loss: 1.9045e-04, Boundary loss: 1.0331e-04, Collocation loss : 7.5748e-05
# Iter 4800, Loss: 3.6903e-04, Initial loss: 1.8848e-04, Boundary loss: 1.0288e-04, Collocation loss : 7.7670e-05
# Iter 4900, Loss: 3.6993e-04, Initial loss: 1.8903e-04, Boundary loss: 1.0339e-04, Collocation loss : 7.7504e-05
# Iter 5000, Loss: 3.6950e-04, Initial loss: 1.9045e-04, Boundary loss: 1.0331e-04, Collocation loss : 7.5748e-05

# %%
loss, error = model.loss, model.error
fig, ax = plt.subplots(1, 2)
ax[0].plot(loss[:100])
ax[0].set_title('Loss')
ax[1].plot(error[:100])
ax[1].set_title('L2 error')
loss = np.array(loss)
error = np.array(error)
# loss_error = np.r_[loss[np.newaxis, :], error[np.newaxis, :]]
# np.save('./data/loss_error_sin.npy', loss_error)
# error.min()

# %%
u_pred, _ = model.predict(model.x_star, model.t_star)
u_pred = u_pred.reshape(200, 200)
plt.subplot(121)
plt.imshow(u_pred)
plt.subplot(122)
plt.imshow(model.u_star.reshape(200, 200))

# %%
plt.subplot(121)
plt.plot(u_pred[10, :])
plt.subplot(122)
plt.plot(model.u_star.reshape(200, 200)[10, :])

# %%
loss_error_sin = np.load('data/loss_error_sin.npy')
loss_error_tanh = np.load('data/loss_error_tanh.npy')
loss_error_softplus = np.load('data/loss_error_softplus.npy')
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(10, 5))
ax[0].plot(loss_error_sin[0][:100], label='sin')
ax[0].plot(loss_error_tanh[0][:100], label='tanh')
ax[0].plot(loss_error_softplus[0][:100], label='softplus')
ax[0].set_xlabel('epochs')
ax[0].set_ylabel('loss')
ax[0].legend()
ax[1].plot(loss_error_sin[1][:100], label='sin')
ax[1].plot(loss_error_tanh[1][:100], label='tanh')
ax[1].plot(loss_error_softplus[1][:100], label='softplus')
ax[1].set_xlabel('epochs')
ax[1].set_ylabel(r'l_2 error')
ax[1].legend()
plt.show()

# %% [markdown]
# We find that different activation function have a strong impact on the training process of PINN. `Sin`, `Tanh` and `Softplus` perform mush better than traditional `ReLU` and `Sigmoid`.
# By compare different optimizer, we find that `Adam` oscillates much heavily than `LBFGS` but take less time to convergence.

# %% [markdown]
# However, when the amplitude of the solution `A` is too small, which is a common case in the simulation process of wave phenomenon, it's hard to tune the hyperparameters. When the network tend to converge, the error of the prediction is still large.

# %%
c = 1
A = 1e-4
Ni = 200
Nb = 200
Nc = 10000
layer_sizes = [2] + [20] * 5 + [1]
model = PINN(c, A, layer_sizes, Ni, Nb, Nc)
model.train()
# Out:
# Iter 0, Loss: 7.7581e-02, Initial loss: 2.5902e-02, Boundary loss: 5.1652e-02, Collocation loss : 2.7350e-05
# Iter 100, Loss: 4.9227e-07, Initial loss: 1.7658e-07, Boundary loss: 9.4596e-08, Collocation loss : 2.2110e-07
# Iter 200, Loss: 4.9106e-07, Initial loss: 1.7618e-07, Boundary loss: 9.3803e-08, Collocation loss : 2.2108e-07
# Iter 300, Loss: 4.9105e-07, Initial loss: 1.7618e-07, Boundary loss: 9.3787e-08, Collocation loss : 2.2108e-07
# Iter 400, Loss: 4.9827e-07, Initial loss: 1.6082e-07, Boundary loss: 1.2350e-07, Collocation loss : 2.1395e-07
# Iter 500, Loss: 4.9119e-07, Initial loss: 1.7618e-07, Boundary loss: 9.3940e-08, Collocation loss : 2.2107e-07
# Iter 600, Loss: 4.9105e-07, Initial loss: 1.7618e-07, Boundary loss: 9.3787e-08, Collocation loss : 2.2108e-07
# Iter 700, Loss: 4.9105e-07, Initial loss: 1.7618e-07, Boundary loss: 9.3787e-08, Collocation loss : 2.2108e-07
# Iter 800, Loss: 4.9227e-07, Initial loss: 1.7658e-07, Boundary loss: 9.4596e-08, Collocation loss : 2.2110e-07
# Iter 900, Loss: 4.9106e-07, Initial loss: 1.7618e-07, Boundary loss: 9.3803e-08, Collocation loss : 2.2108e-07
# Iter 1000, Loss: 4.9105e-07, Initial loss: 1.7618e-07, Boundary loss: 9.3787e-08, Collocation loss : 2.2108e-07
# Iter 1100, Loss: 4.9827e-07, Initial loss: 1.6082e-07, Boundary loss: 1.2350e-07, Collocation loss : 2.1395e-07
# Iter 1200, Loss: 4.9119e-07, Initial loss: 1.7618e-07, Boundary loss: 9.3940e-08, Collocation loss : 2.2107e-07
# Iter 1300, Loss: 4.9105e-07, Initial loss: 1.7618e-07, Boundary loss: 9.3787e-08, Collocation loss : 2.2108e-07
# Iter 1400, Loss: 4.9105e-07, Initial loss: 1.7618e-07, Boundary loss: 9.3787e-08, Collocation loss : 2.2108e-07
# Iter 1500, Loss: 4.9227e-07, Initial loss: 1.7658e-07, Boundary loss: 9.4596e-08, Collocation loss : 2.2110e-07
# Iter 1600, Loss: 4.9106e-07, Initial loss: 1.7618e-07, Boundary loss: 9.3803e-08, Collocation loss : 2.2108e-07
# Iter 1700, Loss: 4.9105e-07, Initial loss: 1.7618e-07, Boundary loss: 9.3787e-08, Collocation loss : 2.2108e-07
# Iter 1800, Loss: 4.9827e-07, Initial loss: 1.6082e-07, Boundary loss: 1.2350e-07, Collocation loss : 2.1395e-07
# Iter 1900, Loss: 4.9119e-07, Initial loss: 1.7618e-07, Boundary loss: 9.3940e-08, Collocation loss : 2.2107e-07
# Iter 2000, Loss: 4.9105e-07, Initial loss: 1.7618e-07, Boundary loss: 9.3787e-08, Collocation loss : 2.2108e-07
# Iter 2100, Loss: 4.9105e-07, Initial loss: 1.7618e-07, Boundary loss: 9.3787e-08, Collocation loss : 2.2108e-07
# Iter 2200, Loss: 4.9227e-07, Initial loss: 1.7658e-07, Boundary loss: 9.4596e-08, Collocation loss : 2.2110e-07
# Iter 2300, Loss: 4.9106e-07, Initial loss: 1.7618e-07, Boundary loss: 9.3803e-08, Collocation loss : 2.2108e-07
# Iter 2400, Loss: 4.9105e-07, Initial loss: 1.7618e-07, Boundary loss: 9.3787e-08, Collocation loss : 2.2108e-07
# Iter 2500, Loss: 4.9827e-07, Initial loss: 1.6082e-07, Boundary loss: 1.2350e-07, Collocation loss : 2.1395e-07
# Iter 2600, Loss: 4.9119e-07, Initial loss: 1.7618e-07, Boundary loss: 9.3940e-08, Collocation loss : 2.2107e-07
# Iter 2700, Loss: 4.9105e-07, Initial loss: 1.7618e-07, Boundary loss: 9.3787e-08, Collocation loss : 2.2108e-07
# Iter 2800, Loss: 4.9105e-07, Initial loss: 1.7618e-07, Boundary loss: 9.3787e-08, Collocation loss : 2.2108e-07
# Iter 2900, Loss: 4.9227e-07, Initial loss: 1.7658e-07, Boundary loss: 9.4596e-08, Collocation loss : 2.2110e-07
# Iter 3000, Loss: 4.9106e-07, Initial loss: 1.7618e-07, Boundary loss: 9.3803e-08, Collocation loss : 2.2108e-07
# Iter 3100, Loss: 4.9105e-07, Initial loss: 1.7618e-07, Boundary loss: 9.3787e-08, Collocation loss : 2.2108e-07
# Iter 3200, Loss: 4.9827e-07, Initial loss: 1.6082e-07, Boundary loss: 1.2350e-07, Collocation loss : 2.1395e-07
# Iter 3300, Loss: 4.9119e-07, Initial loss: 1.7618e-07, Boundary loss: 9.3940e-08, Collocation loss : 2.2107e-07
# Iter 3400, Loss: 4.9105e-07, Initial loss: 1.7618e-07, Boundary loss: 9.3787e-08, Collocation loss : 2.2108e-07
# Iter 3500, Loss: 4.9105e-07, Initial loss: 1.7618e-07, Boundary loss: 9.3787e-08, Collocation loss : 2.2108e-07
# Iter 3600, Loss: 4.9227e-07, Initial loss: 1.7658e-07, Boundary loss: 9.4596e-08, Collocation loss : 2.2110e-07
# Iter 3700, Loss: 4.9106e-07, Initial loss: 1.7618e-07, Boundary loss: 9.3803e-08, Collocation loss : 2.2108e-07
# Iter 3800, Loss: 4.9105e-07, Initial loss: 1.7618e-07, Boundary loss: 9.3787e-08, Collocation loss : 2.2108e-07
# Iter 3900, Loss: 4.9827e-07, Initial loss: 1.6082e-07, Boundary loss: 1.2350e-07, Collocation loss : 2.1395e-07
# Iter 4000, Loss: 4.9119e-07, Initial loss: 1.7618e-07, Boundary loss: 9.3940e-08, Collocation loss : 2.2107e-07
# Iter 4100, Loss: 4.9105e-07, Initial loss: 1.7618e-07, Boundary loss: 9.3787e-08, Collocation loss : 2.2108e-07
# Iter 4200, Loss: 4.9105e-07, Initial loss: 1.7618e-07, Boundary loss: 9.3787e-08, Collocation loss : 2.2108e-07
# Iter 4300, Loss: 4.9227e-07, Initial loss: 1.7658e-07, Boundary loss: 9.4596e-08, Collocation loss : 2.2110e-07
# Iter 4400, Loss: 4.9106e-07, Initial loss: 1.7618e-07, Boundary loss: 9.3803e-08, Collocation loss : 2.2108e-07
# Iter 4500, Loss: 4.9105e-07, Initial loss: 1.7618e-07, Boundary loss: 9.3787e-08, Collocation loss : 2.2108e-07
# Iter 4600, Loss: 4.9827e-07, Initial loss: 1.6082e-07, Boundary loss: 1.2350e-07, Collocation loss : 2.1395e-07
# Iter 4700, Loss: 4.9119e-07, Initial loss: 1.7618e-07, Boundary loss: 9.3940e-08, Collocation loss : 2.2107e-07
# Iter 4800, Loss: 4.9105e-07, Initial loss: 1.7618e-07, Boundary loss: 9.3787e-08, Collocation loss : 2.2108e-07
# Iter 4900, Loss: 4.9105e-07, Initial loss: 1.7618e-07, Boundary loss: 9.3787e-08, Collocation loss : 2.2108e-07
# Iter 5000, Loss: 4.9227e-07, Initial loss: 1.7658e-07, Boundary loss: 9.4596e-08, Collocation loss : 2.2110e-07

# %%
loss, error = model.loss, model.error
fig, ax = plt.subplots(1, 2)
ax[0].plot(loss[:100])
ax[0].set_title('Loss')
ax[1].plot(error[:100])
ax[1].set_title('L2 error')
loss = np.array(loss)
error = np.array(error)
print(f'The lowest error is {error.min():.4f}')
# Out:
# The lowest error is 17.1031

# %%
u_pred, _ = model.predict(model.x_star, model.t_star)
u_pred = u_pred.reshape(200, 200)
plt.subplot(121)
plt.imshow(u_pred)
plt.subplot(122)
plt.imshow(model.u_star.reshape(200, 200))

# %% [markdown]
# In machine learning, we always normalize or standardize the inputs and outputs of the network to accelerate the training process.

# %%
class PINN(nn.Module):
    """Physic informed neural network
    """
    def __init__(self, c, A, layer_sizes, Ni, Nb, Nc):
        super(PINN, self).__init__()
        self.c = c
        self.A = A
        # Initial condition
        xi = np.random.uniform(-1, 1, (Ni, 1))
        self.xi = torch.tensor(xi, dtype=torch.float32, requires_grad=True, device=device)
        self.ti = torch.zeros(Ni, 1, dtype=torch.float32, requires_grad=True, device=device)
        ui = np.cos(np.pi * xi / 2) * A
        self.ui = torch.tensor(ui, dtype=torch.float32, device=device)
        self.ui_max = self.ui.max()
        self.ui_min = self.ui.min()
        
        # Boundary condition
        tl = np.random.uniform(0, 1, (Nb, 1))
        xl = np.ones((Nb, 1)) * (-1)
        self.tl = torch.tensor(tl, dtype=torch.float32, requires_grad=True, device=device)
        self.xl = torch.tensor(xl, dtype=torch.float32, requires_grad=True, device=device)
        tr = np.random.uniform(0, 1, (Nb, 1))
        xr = np.ones((Nb, 1))  
        self.tr = torch.tensor(tr, dtype=torch.float32, requires_grad=True, device=device)
        self.xr = torch.tensor(xr, dtype=torch.float32, requires_grad=True, device=device)        
        
        # Collocation points
        xf = np.random.uniform(-1, 1, (Nc, 1))
        tf = np.random.uniform(0, 1, (Nc, 1))
        self.xf = torch.tensor(xf, dtype=torch.float32, requires_grad=True, device=device)
        self.tf = torch.tensor(tf, dtype=torch.float32, requires_grad=True, device=device)
        
        # Deal with l2 error
        self.error = []
        t_star = np.linspace(0, 1, 200)[:, None]
        x_star = np.linspace(0, 1, 200)[:, None]
        X_star, T_star = np.meshgrid(x_star, t_star)
        self.t_star = T_star.flatten()[:,None]
        self.x_star = X_star.flatten()[:,None]
        self.u_star = np.cos(np.pi * c * self.t_star / 2) * np.cos(np.pi * self.x_star / 2) * A
            
        self.loss = []
        self.dnn = DNN(layer_sizes).to(device)
        self.iter = 0
        self.max_num_iter = 5000
        self.optimizer = torch.optim.LBFGS(
            self.dnn.parameters(), 
            lr=1.0, 
            max_iter=50000, 
            max_eval=50000, 
            history_size=50,
            tolerance_grad=1e-5, 
            tolerance_change=1.0 * np.finfo(float).eps,
            line_search_fn="strong_wolfe"       # can be "strong_wolfe"
        )
        
#         self.optimizer = torch.optim.Adam(
#             self.dnn.parameters(), 
#             lr=0.01, 
#         )
        
    def net_u(self, x, t):
        u = self.dnn(torch.cat((x, t), dim=1)) * (self.ui_max - self.ui_min) + self.ui_min
        return u 

    def net_f(self, x, t):
        u = self.net_u(x, t)

        u_t = torch.autograd.grad(
            u, t, 
            grad_outputs=torch.ones_like(u),
            retain_graph=True,
            create_graph=True
        )[0]
        
        u_tt = torch.autograd.grad(
            u_t, t, 
            grad_outputs=torch.ones_like(u_t),
            retain_graph=True,
            create_graph=True
        )[0]

        u_x = torch.autograd.grad(
            u, x, 
            grad_outputs=torch.ones_like(u),
            retain_graph=True,
            create_graph=True
        )[0]

        u_xx = torch.autograd.grad(
            u_x, x, 
            grad_outputs=torch.ones_like(u_x),
            retain_graph=True,
            create_graph=True
        )[0]

        Lu = u_tt  - self.c ** 2 * u_xx
        return Lu 

    def compute_error(self):
        self.dnn.eval()
        u_pred, _ = self.predict(self.x_star, self.t_star)
        error = np.linalg.norm(self.u_star-u_pred,2)/np.linalg.norm(self.u_star,2)
        error = error ** 2
        self.error.append(error)
        self.dnn.train()

    def loss_func(self):
        self.compute_error()
        self.optimizer.zero_grad()
        
        ui = self.net_u(self.xi, self.ti)
        ui_t = torch.autograd.grad(
            ui, self.ti,
            grad_outputs=torch.ones_like(ui),
            retain_graph=True,
            create_graph=True
        )[0]
        loss_i = torch.mean((self.ui - ui) ** 2) + torch.mean(ui_t ** 2)
        
        f_pred = self.net_f(self.xf, self.tf)
        loss_f = torch.mean(f_pred ** 2)
        
        ul = self.net_u(self.xl, self.tl)
        ur = self.net_u(self.xr, self.tr)
        loss_b = torch.mean(ul ** 2) + torch.mean(ur ** 2)

        loss = (loss_i + loss_b +  loss_f) / (self.A ** 2)
        self.loss.append(loss.item())
        
        loss.backward()
        
        if self.iter % 500 == 0:
            print("Iter %d, Loss: %.4e, Initial loss: %.4e, Boundary loss: %.4e, Collocation loss : %.4e" 
                  % (self.iter, loss.item(), loss_i.item(), loss_b.item(), loss_f.item()))
        self.iter += 1
        return loss
    
    def train(self):
        self.dnn.train()
        while self.iter < self.max_num_iter:
            self.optimizer.step(self.loss_func)

            
    def predict(self, x, t):
        self.dnn.eval() 
        x = torch.tensor(x, requires_grad=True, dtype=torch.float32, device=device)
        t = torch.tensor(t, requires_grad=True, dtype=torch.float32, device=device)
        u = self.net_u(x, t)
        Lu = self.net_f(x, t)
        u = u.detach().cpu().numpy()
        Lu = Lu.detach().cpu().numpy()
        return u, Lu

# %%
c = 1
A = 1e-4
Ni = 200
Nb = 200
Nc = 10000
layer_sizes = [2] + [20] * 5 + [1]
model = PINN(c, A, layer_sizes, Ni, Nb, Nc)
model.train()
# Out:
# Iter 0, Loss: 6.3386e-01, Initial loss: 6.1586e-09, Boundary loss: 1.7992e-10, Collocation loss : 1.1864e-14
# Iter 500, Loss: 5.7897e-04, Initial loss: 1.4037e-12, Boundary loss: 1.9390e-13, Collocation loss : 4.1921e-12
# Iter 1000, Loss: 5.7910e-04, Initial loss: 1.4050e-12, Boundary loss: 1.9421e-13, Collocation loss : 4.1918e-12
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_683/3618810101.py in <module>
#       6 layer_sizes = [2] + [20] * 5 + [1]
#       7 model = PINN(c, A, layer_sizes, Ni, Nb, Nc)
# ----> 8 model.train()
#
# /tmp/ipykernel_683/3539962206.py in train(self)
#     140         self.dnn.train()
#     141         while self.iter < self.max_num_iter:
# --> 142             self.optimizer.step(self.loss_func)
#     143
#     144
#
# ~/install/envs/cuda/lib/python3.9/site-packages/torch/optim/optimizer.py in wrapper(*args, **kwargs)
#      86                 profile_name = "Optimizer.step#{}.step".format(obj.__class__.__name__)
#      87                 with torch.autograd.profiler.record_function(profile_name):
# ---> 88                     return func(*args, **kwargs)
#      89             return wrapper
#      90
#
# ~/install/envs/cuda/lib/python3.9/site-packages/torch/autograd/grad_mode.py in decorate_context(*args, **kwargs)
#      26         def decorate_context(*args, **kwargs):
#      27             with self.__class__():
# ---> 28                 return func(*args, **kwargs)
#      29         return cast(F, decorate_context)
#      30
#
# ~/install/envs/cuda/lib/python3.9/site-packages/torch/optim/lbfgs.py in step(self, closure)
#     423                         return self._directional_evaluate(closure, x, t, d)
#     424
# --> 425                     loss, flat_grad, t, ls_func_evals = _strong_wolfe(
#     426                         obj_func, x_init, t, d, loss, flat_grad, gtd)
#     427                 self._add_grad(t, d)
#
# ~/install/envs/cuda/lib/python3.9/site-packages/torch/optim/lbfgs.py in _strong_wolfe(obj_func, x, t, d, f, g, gtd, c1, c2, tolerance_change, max_ls)
#     145
#     146         # Evaluate new point
# --> 147         f_new, g_new = obj_func(x, t, d)
#     148         ls_func_evals += 1
#     149         gtd_new = g_new.dot(d)
#
# ~/install/envs/cuda/lib/python3.9/site-packages/torch/optim/lbfgs.py in obj_func(x, t, d)
#     421
#     422                     def obj_func(x, t, d):
# --> 423                         return self._directional_evaluate(closure, x, t, d)
#     424
#     425                     loss, flat_grad, t, ls_func_evals = _strong_wolfe(
#
# ~/install/envs/cuda/lib/python3.9/site-packages/torch/optim/lbfgs.py in _directional_evaluate(self, closure, x, t, d)
#     275     def _directional_evaluate(self, closure, x, t, d):
#     276         self._add_grad(t, d)
# --> 277         loss = float(closure())
#     278         flat_grad = self._gather_flat_grad()
#     279         self._set_param(x)
#
# ~/install/envs/cuda/lib/python3.9/site-packages/torch/autograd/grad_mode.py in decorate_context(*args, **kwargs)
#      26         def decorate_context(*args, **kwargs):
#      27             with self.__class__():
# ---> 28                 return func(*args, **kwargs)
#      29         return cast(F, decorate_context)
#      30
#
# /tmp/ipykernel_683/3539962206.py in loss_func(self)
#     119         loss_i = torch.mean((self.ui - ui) ** 2) + torch.mean(ui_t ** 2)
#     120
# --> 121         f_pred = self.net_f(self.xf, self.tf)
#     122         loss_f = torch.mean(f_pred ** 2)
#     123
#
# /tmp/ipykernel_683/3539962206.py in net_f(self, x, t)
#      88         )[0]
#      89
# ---> 90         u_xx = torch.autograd.grad(
#      91             u_x, x,
#      92             grad_outputs=torch.ones_like(u_x),
#
# ~/install/envs/cuda/lib/python3.9/site-packages/torch/autograd/__init__.py in grad(outputs, inputs, grad_outputs, retain_graph, create_graph, only_inputs, allow_unused)
#     232         retain_graph = create_graph
#     233
# --> 234     return Variable._execution_engine.run_backward(
#     235         outputs, grad_outputs_, retain_graph, create_graph,
#     236         inputs, allow_unused, accumulate_grad=False)
#
# KeyboardInterrupt:

# %%
loss, error = model.loss, model.error
fig, ax = plt.subplots(1, 2)
ax[0].plot(loss[:100])
ax[0].set_title('Loss')
ax[1].plot(error[:100])
ax[1].set_title('L2 error')
loss = np.array(loss)
error = np.array(error)
print(f'The lowest error is {error.min():.8f}')
# Out:
# The lowest error is 0.00001029

# %%
u_pred, _ = model.predict(model.x_star, model.t_star)
u_pred = u_pred.reshape(200, 200)
fig, ax = plt.subplots(1, 2)
ax0 = ax[0].imshow(u_pred)
ax1 = ax[1].imshow(model.u_star.reshape(200, 200))
fig.colorbar(ax0, ax=ax[0])
fig.colorbar(ax1, ax=ax[1])
plt.show()

# %%
plt.subplot(121)
plt.plot(u_pred[10, :])
plt.subplot(122)
plt.plot(model.u_star.reshape(200, 200)[10, :])
